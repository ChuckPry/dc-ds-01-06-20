# %%
import requests
import json
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from sodapy import Socrata

# %%
# !pip install sodapy

# %%
requests.get('http://www.medicare.gov')
# Out:
# <Response [200]>

# %%
# data = requests.get('https://data.medicare.gov/resource/r5ix-sfxw.json',
#                      83zy7medj7g25xuqoi7tvqgh7)
params = []
client = Socrata('data.medicare.gov',
                 "jwvG8bQIIY0Fh4gZPLATBoUeg",
                 username="charlespryor312@yahoo.com",
                 password="Cj03!2!977")
results = client.get("r5ix-sfxw", limit = 365000  )

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365000 entries, 0 to 364999
# Data columns (total 23 columns):
# federal_provider_number        365000 non-null object
# provider_name                  365000 non-null object
# provider_address               365000 non-null object
# provider_city                  365000 non-null object
# provider_state                 365000 non-null object
# provider_zip_code              365000 non-null object
# survey_date                    365000 non-null object
# survey_type                    365000 non-null object
# deficiency_prefix              365000 non-null object
# deficiency_category            365000 non-null object
# deficiency_description         365000 non-null object
# deficiency_tag_number          365000 non-null object
# scope_severity_code            365000 non-null object
# deficiency_corrected           365000 non-null object
# correction_date                363466 non-null object
# ...

# %%
results_df['provider_state'] == 'CA'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 364995    False
# 364996    False
# 364997    False
# 364998    False
# 364999    False
# Name: provider_state, Length: 365000, dtype: bool

# %%
md_nursing_homes = results_df.loc[results_df['provider_state'] == 'MD']
md_nursing_homes
# Out:
#        federal_provider_number  \
# 728                     215090
# 736                     215133
# 744                     215184
# 747                     215216
# 759                     215277
# ...                        ...
# 149464                  215266
# 149471                  215320
# 149472                  215329
# 149473                  215341
# 149478                  215316
#
#                                            provider_name  \
# 728                                    LOCH RAVEN CENTER
# 736                             CARROLL LUTHERAN VILLAGE
# 744             FREDERICK HEALTH & REHABILITATION CENTER
# 747                                   DENNETT ROAD MANOR
# 759     WEST MD HEALTH SYST FROSTBURG NRSG AND REHAB CTR
# ...                                                  ...
# 149464      GLEN BURNIE HEALTH AND REHABILITATION CENTER
# 149471                BRIGHTON GARDENS OF TUCKERMAN LANE
# 149472                               BUCKINGHAM'S CHOICE
# ...

# %%
ca_nursing_homes = results_df.loc[results_df['provider_state'] == 'CA']
ca_nursing_homes
# Out:
#        federal_provider_number  \
# 54                      055017
# 55                      055028
# 56                      055039
# 57                      055056
# 58                      055064
# ...                        ...
# 347120                  555450
# 347121                  555799
# 347122                  555797
# 347123                  555583
# 347124                  555753
#
#                                             provider_name  \
# 54         HEARTS & HANDS, POST ACUTE CARE & REHAB CENTER
# 55              LOS BANOS NURSING & REHABILITATION CENTER
# 56                   GOOD SAMARITAN REHAB AND CARE CENTER
# 57            PINE GROVE HEALTHCARE & WELLNESS CENTRE, LP
# 58                    COTTONWOOD CANYON HEALTHCARE CENTER
# ...                                                   ...
# 347120                              AMERICAN RIVER CENTER
# 347121                        MT. PLEASANT NURSING CENTER
# ...

# %%
ca_nursing_homes1 = ca_nursing_homes[['provider_name', 'provider_state','deficiency_category','deficiency_corrected','correction_date','complaint_deficiency','deficiency_description','scope_severity_code','deficiency_tag_number']]

# %%
ca_nursing_homes1
# Out:
#                                             provider_name provider_state  \
# 54         HEARTS & HANDS, POST ACUTE CARE & REHAB CENTER             CA
# 55              LOS BANOS NURSING & REHABILITATION CENTER             CA
# 56                   GOOD SAMARITAN REHAB AND CARE CENTER             CA
# 57            PINE GROVE HEALTHCARE & WELLNESS CENTRE, LP             CA
# 58                    COTTONWOOD CANYON HEALTHCARE CENTER             CA
# ...                                                   ...            ...
# 347120                              AMERICAN RIVER CENTER             CA
# 347121                        MT. PLEASANT NURSING CENTER             CA
# 347122                            GORDON LANE CARE CENTER             CA
# 347123                           MACLAY HEALTHCARE CENTER             CA
# 347124  HEALTHBRIDGE CHILDREN'S HOSPITAL - ORANGE D/P SNF             CA
#
#                                       deficiency_category  \
# ...

# %%
md_nursing_homes1 = md_nursing_homes[['provider_name', 'provider_state','deficiency_category','deficiency_corrected','correction_date','complaint_deficiency','deficiency_description','scope_severity_code','deficiency_tag_number']]
md_nursing_homes1
# Out:
#                                            provider_name provider_state  \
# 728                                    LOCH RAVEN CENTER             MD
# 736                             CARROLL LUTHERAN VILLAGE             MD
# 744             FREDERICK HEALTH & REHABILITATION CENTER             MD
# 747                                   DENNETT ROAD MANOR             MD
# 759     WEST MD HEALTH SYST FROSTBURG NRSG AND REHAB CTR             MD
# ...                                                  ...            ...
# 149464      GLEN BURNIE HEALTH AND REHABILITATION CENTER             MD
# 149471                BRIGHTON GARDENS OF TUCKERMAN LANE             MD
# 149472                               BUCKINGHAM'S CHOICE             MD
# 149473                     LORIEN NSG & REHAB CTR BELAIR             MD
# 149478    NORTH ARUNDEL HEALTH AND REHABILITATION CENTER             MD
#
#                                       deficiency_category  \
# ...
