# %%
import requests
import json
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from sodapy import Socrata

# %%
# !pip install sodapy

# %%
requests.get('http://www.medicare.gov')
# Out:
# <Response [200]>

# %%
# data = requests.get('https://data.medicare.gov/resource/r5ix-sfxw.json',
#                      83zy7medj7g25xuqoi7tvqgh7)
params = []
client = Socrata('data.medicare.gov',
                 "jwvG8bQIIY0Fh4gZPLATBoUeg",
                 username="charlespryor312@yahoo.com",
                 password="Cj03!2!977")
results = client.get("r5ix-sfxw", limit = 365000  )

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365000 entries, 0 to 364999
# Data columns (total 23 columns):
# federal_provider_number        365000 non-null object
# provider_name                  365000 non-null object
# provider_address               365000 non-null object
# provider_city                  365000 non-null object
# provider_state                 365000 non-null object
# provider_zip_code              365000 non-null object
# survey_date                    365000 non-null object
# survey_type                    365000 non-null object
# deficiency_prefix              365000 non-null object
# deficiency_category            365000 non-null object
# deficiency_description         365000 non-null object
# deficiency_tag_number          365000 non-null object
# scope_severity_code            365000 non-null object
# deficiency_corrected           365000 non-null object
# correction_date                363466 non-null object
# ...

# %%
results_df['provider_state'] == 'CA'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 364995    False
# 364996    False
# 364997    False
# 364998    False
# 364999    False
# Name: provider_state, Length: 365000, dtype: bool

# %%
md_nursing_homes = results_df.loc[results_df['provider_state'] == 'MD']
md_nursing_homes
# Out:
#        federal_provider_number  \
# 728                     215090
# 736                     215133
# 744                     215184
# 747                     215216
# 759                     215277
# ...                        ...
# 149464                  215266
# 149471                  215320
# 149472                  215329
# 149473                  215341
# 149478                  215316
#
#                                            provider_name  \
# 728                                    LOCH RAVEN CENTER
# 736                             CARROLL LUTHERAN VILLAGE
# 744             FREDERICK HEALTH & REHABILITATION CENTER
# 747                                   DENNETT ROAD MANOR
# 759     WEST MD HEALTH SYST FROSTBURG NRSG AND REHAB CTR
# ...                                                  ...
# 149464      GLEN BURNIE HEALTH AND REHABILITATION CENTER
# 149471                BRIGHTON GARDENS OF TUCKERMAN LANE
# 149472                               BUCKINGHAM'S CHOICE
# ...

# %%
ca_nursing_homes = results_df.loc[results_df['provider_state'] == 'CA']
ca_nursing_homes
# Out:
#        federal_provider_number  \
# 54                      055017
# 55                      055028
# 56                      055039
# 57                      055056
# 58                      055064
# ...                        ...
# 347120                  555450
# 347121                  555799
# 347122                  555797
# 347123                  555583
# 347124                  555753
#
#                                             provider_name  \
# 54         HEARTS & HANDS, POST ACUTE CARE & REHAB CENTER
# 55              LOS BANOS NURSING & REHABILITATION CENTER
# 56                   GOOD SAMARITAN REHAB AND CARE CENTER
# 57            PINE GROVE HEALTHCARE & WELLNESS CENTRE, LP
# 58                    COTTONWOOD CANYON HEALTHCARE CENTER
# ...                                                   ...
# 347120                              AMERICAN RIVER CENTER
# 347121                        MT. PLEASANT NURSING CENTER
# ...

# %%
ca_nursing_homes1 = ca_nursing_homes[['provider_name', 'provider_state','survey_date','deficiency_category','deficiency_corrected','correction_date','complaint_deficiency','deficiency_description','scope_severity_code','deficiency_tag_number']]

# %%
ca_nursing_homes1
# Out:
#                                             provider_name provider_state  \
# 54         HEARTS & HANDS, POST ACUTE CARE & REHAB CENTER             CA
# 55              LOS BANOS NURSING & REHABILITATION CENTER             CA
# 56                   GOOD SAMARITAN REHAB AND CARE CENTER             CA
# 57            PINE GROVE HEALTHCARE & WELLNESS CENTRE, LP             CA
# 58                    COTTONWOOD CANYON HEALTHCARE CENTER             CA
# ...                                                   ...            ...
# 347120                              AMERICAN RIVER CENTER             CA
# 347121                        MT. PLEASANT NURSING CENTER             CA
# 347122                            GORDON LANE CARE CENTER             CA
# 347123                           MACLAY HEALTHCARE CENTER             CA
# 347124  HEALTHBRIDGE CHILDREN'S HOSPITAL - ORANGE D/P SNF             CA
#
#                     survey_date  \
# 54      2018-12-10T00:00:00.000
# ...

# %%
md_nursing_homes1 = md_nursing_homes[['provider_name', 'provider_state','survey_date', 'deficiency_category','deficiency_corrected','correction_date','complaint_deficiency','deficiency_description','scope_severity_code','deficiency_tag_number']]
md_nursing_homes1
# Out:
#                                            provider_name provider_state  \
# 728                                    LOCH RAVEN CENTER             MD
# 736                             CARROLL LUTHERAN VILLAGE             MD
# 744             FREDERICK HEALTH & REHABILITATION CENTER             MD
# 747                                   DENNETT ROAD MANOR             MD
# 759     WEST MD HEALTH SYST FROSTBURG NRSG AND REHAB CTR             MD
# ...                                                  ...            ...
# 149464      GLEN BURNIE HEALTH AND REHABILITATION CENTER             MD
# 149471                BRIGHTON GARDENS OF TUCKERMAN LANE             MD
# 149472                               BUCKINGHAM'S CHOICE             MD
# 149473                     LORIEN NSG & REHAB CTR BELAIR             MD
# 149478    NORTH ARUNDEL HEALTH AND REHABILITATION CENTER             MD
#
#                     survey_date  \
# 728     2016-08-04T00:00:00.000
# 736     2017-06-26T00:00:00.000
# ...

# %%
df5 = pd.read_csv('Datafiniti_Fast_Food_Restaurants.csv')

# %%
df5
# Out:
#                         id             dateAdded           dateUpdated  \
# 0     AVwcmSyZIN2L1WUfmxyw  2015-10-19T23:47:58Z  2018-06-26T03:00:14Z
# 1     AVwcmSyZIN2L1WUfmxyw  2015-10-19T23:47:58Z  2018-06-26T03:00:14Z
# 2     AVwcopQoByjofQCxgfVa  2016-03-29T05:06:36Z  2018-06-26T02:59:52Z
# 3     AVweXN5RByjofQCxxilK  2017-01-03T07:46:11Z  2018-06-26T02:59:51Z
# 4     AWQ6MUvo3-Khe5l_j3SG  2018-06-26T02:59:43Z  2018-06-26T02:59:43Z
# ...                    ...                   ...                   ...
# 9995  AV12gJwna4HuVbed9Ayg  2017-07-24T21:28:46Z  2018-04-07T13:19:06Z
# 9996  AV12gJxKIxWefVJwhpzS  2017-07-24T21:28:46Z  2018-04-07T13:19:05Z
# 9997  AVwdJMdSByjofQCxl8Vr  2015-10-24T00:17:32Z  2018-04-07T13:19:05Z
# 9998  AVwdl2cykufWRAb57ZPs  2016-04-05T02:59:45Z  2018-04-07T13:19:05Z
# 9999  AVwdecWKIN2L1WUfwMWU  2016-11-08T02:26:32Z  2018-04-07T13:19:05Z
#
#                    address                                    categories  \
# ...

# %%
df6 = df5.loc[df5['province'] == 'CA']
df6
# Out:
#                         id             dateAdded           dateUpdated  \
# 7     AVwdVafPByjofQCxoA6y  2016-06-06T16:15:08Z  2018-06-26T02:59:41Z
# 14    AVwdnJWakufWRAb57mV7  2015-10-23T02:52:53Z  2018-06-25T09:32:43Z
# 17    AVyoBhJfl8hL2jjQySvt  2017-06-14T19:13:09Z  2018-06-25T09:31:55Z
# 70    AVwePo1-_7pvs4fzBS_K  2016-03-26T04:52:32Z  2018-06-25T09:00:55Z
# 71    AVzX86OvLD2H7whiWxXf  2017-06-24T02:34:47Z  2018-06-25T09:00:55Z
# ...                    ...                   ...                   ...
# 9983  AVwc_nY-_7pvs4fz1JLN  2016-03-27T05:39:41Z  2018-04-07T23:40:07Z
# 9990  AVzA03GB-gnIPe8DSb_F  2017-06-19T14:48:21Z  2018-04-07T23:39:53Z
# 9991  AVzA1f16-gnIPe8DScq9  2017-06-19T14:51:08Z  2018-04-07T23:39:53Z
# 9992  AVzA2T59-gnIPe8DSdWc  2017-06-19T14:54:41Z  2018-04-07T23:39:52Z
# 9993  AVwePGLgIN2L1WUf3Keg  2015-11-02T15:34:13Z  2018-04-07T23:39:50Z
#
#                          address             categories          city country  \
# ...

# %%
df7 = df6[['name','city','province','postalCode']]

# %%
df7
# Out:
#                         name          city province postalCode
# 7     Chipotle Mexican Grill     Oceanside       CA      92056
# 14                 Carl's Jr         Azusa       CA      91702
# 17                    Togo's   Los Angeles       CA      90045
# 70               Burger King      El Cajon       CA      92019
# 71             Boston Market      El Cajon       CA      92020
# ...                      ...           ...      ...        ...
# 9983                  SUBWAY     Inglewood       CA      90304
# 9990         Jack in the Box  Port Hueneme       CA      93041
# 9991              McDonald's  Port Hueneme       CA      93041
# 9992                     KFC  Port Hueneme       CA      93041
# 9993              McDonald's        Oxnard       CA      93033
#
# [1201 rows x 4 columns]

# %%
df8_sd = df7.loc[df7['postalCode'] == (ziplist)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-115-24b3c68c7fb3> in <module>
# ----> 1 df8_sd = df7.loc[df7['postalCode'] == (ziplist)]
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/ops/__init__.py in wrapper(self, other, axis)
#    1205             # as it will broadcast
#    1206             if other.ndim != 0 and len(self) != len(other):
# -> 1207                 raise ValueError("Lengths must match to compare")
#    1208
#    1209             res_values = na_op(self.values, np.asarray(other))
#
# ValueError: Lengths must match to compare

# %%
ziplist = [92132, 92163, 92196, 92153, 92161, 92152, 92143, 92192, 92138, 92182, 92199, 92198, 92140, 92150, 92038, 92112, 92093, 92145, 92092, 92091, 92173, 92027, 92118, 92106, 92124, 92119, 92107, 92116, 92139, 92029, 92102, 92113, 92071, 92104, 92025, 92110, 92120, 91945, 92105, 92037, 92103, 92114, 92129, 92117, 91942, 92122, 92128, 91932, 92108, 92111, 92109, 92131, 92126, 92127, 92123, 92115, 92121, 92154, 92130, 92101, 91911]

# %%
df8_sd
# Out:
# Empty DataFrame
# Columns: [name, city, province, postalCode]
# Index: []
